# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Display graphs inside notebook
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("../datasets/personal_finance_dataset_8000_extended.csv")

# %%
df.head()
# Out:
#          Date          Description    Amount         Category PaymentMethod  \
# 0  05-04-2025                IRCTC  20666.49           Travel    Debit Card
# 1  06-12-2025               Myntra   1919.05  Online Shopping   Net Banking
# 2  20-06-2025            BigBazaar   2837.68          Grocery    Debit Card
# 3  23-04-2025  Property Tax Online   1071.04            Bills   Net Banking
# 4  06-03-2025           Asus Store  10722.80      Electronics    Debit Card
#
#       Month
# 0     April
# 1  December
# 2      June
# 3     April
# 4     March

# %%
df.shape
# Out:
# (8000, 6)

# %%
df.columns
# Out:
# Index(['Date', 'Description', 'Amount', 'Category', 'PaymentMethod', 'Month'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8000 non-null   str
#  1   Description    8000 non-null   str
#  2   Amount         8000 non-null   float64
#  3   Category       8000 non-null   str
#  4   PaymentMethod  8000 non-null   str
#  5   Month          8000 non-null   str
# dtypes: float64(1), str(5)
# memory usage: 375.1 KB

# %%
df.isnull().sum()
# Out:
# Date             0
# Description      0
# Amount           0
# Category         0
# PaymentMethod    0
# Month            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Date                 str
# Description          str
# Amount           float64
# Category             str
# PaymentMethod        str
# Month                str
# dtype: object

# %%
df.describe()
# Out:
#               Amount
# count    8000.000000
# mean    12551.954504
# std     26196.803575
# min        54.110000
# 25%       938.920000
# 50%      3328.625000
# 75%     11173.300000
# max    149925.200000

# %%
df["Category"].value_counts()
# Out:
# Category
# Online Shopping    831
# Entertainment      824
# Food               822
# Healthcare         804
# Electronics        797
# Travel             789
# Bills              788
# Grocery            786
# Transport          786
# Clothing           773
# Name: count, dtype: int64

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Net Banking    2023
# Credit Card    2023
# Debit Card     1993
# UPI            1961
# Name: count, dtype: int64

# %%
print(df["Category"].unique())
print("\nNumber of Categories:", df["Category"].nunique())
# Out:
# <StringArray>
# [         'Travel', 'Online Shopping',         'Grocery',           'Bills',
#      'Electronics',        'Clothing',   'Entertainment',            'Food',
#        'Transport',      'Healthcare']
# Length: 10, dtype: str
#
# Number of Categories: 10

# %%
df["Description"] = df["Description"].str.lower()

# %%
df["Description"] = df["Description"].str.strip()

# %%
df.head()
# Out:
#          Date          Description    Amount         Category PaymentMethod  \
# 0  05-04-2025                irctc  20666.49           Travel    Debit Card
# 1  06-12-2025               myntra   1919.05  Online Shopping   Net Banking
# 2  20-06-2025            bigbazaar   2837.68          Grocery    Debit Card
# 3  23-04-2025  property tax online   1071.04            Bills   Net Banking
# 4  06-03-2025           asus store  10722.80      Electronics    Debit Card
#
#       Month
# 0     April
# 1  December
# 2      June
# 3     April
# 4     March

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8000 non-null   datetime64[us]
#  1   Description    8000 non-null   str
#  2   Amount         8000 non-null   float64
#  3   Category       8000 non-null   str
#  4   PaymentMethod  8000 non-null   str
#  5   Month          8000 non-null   str
# dtypes: datetime64[us](1), float64(1), str(4)
# memory usage: 375.1 KB

# %%
df["Year"] = df["Date"].dt.year
df["Month_Number"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Weekday"] = df["Date"].dt.day_name()

# %%
df.head()
# Out:
#         Date          Description    Amount         Category PaymentMethod  \
# 0 2025-04-05                irctc  20666.49           Travel    Debit Card
# 1 2025-12-06               myntra   1919.05  Online Shopping   Net Banking
# 2 2025-06-20            bigbazaar   2837.68          Grocery    Debit Card
# 3 2025-04-23  property tax online   1071.04            Bills   Net Banking
# 4 2025-03-06           asus store  10722.80      Electronics    Debit Card
#
#       Month  Year  Month_Number  Day    Weekday
# 0     April  2025             4    5   Saturday
# 1  December  2025            12    6   Saturday
# 2      June  2025             6   20     Friday
# 3     April  2025             4   23  Wednesday
# 4     March  2025             3    6   Thursday

# %%
df.to_csv("../datasets/cleaned_dataset.csv", index=False)

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x="Category",
    order=df["Category"].value_counts().index
)

plt.title("Number of Transactions per Category")
plt.xticks(rotation=45)
plt.show()

# %%
category_spending = (
    df.groupby("Category")["Amount"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))

category_spending.plot(kind="bar")

plt.title("Total Spending by Category")

plt.ylabel("Amount")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="PaymentMethod"
)

plt.title("Payment Method Usage")

plt.show()

# %%
payment_counts = df["PaymentMethod"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    payment_counts,
    labels=payment_counts.index,
    autopct="%1.1f%%"
)

plt.title("Payment Method Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["Amount"],
    bins=30
)

plt.title("Distribution of Transaction Amount")

plt.show()

# %%
monthly_spending = (
    df.groupby("Month")["Amount"]
      .sum()
)

# %%
monthly_spending
# Out:
# Month
# April        7937485.11
# August       8692664.18
# December     8391272.78
# February     7327831.77
# January      8093666.23
# July         8951073.24
# June         9018844.54
# March        9390091.29
# May          8847821.63
# November     8039843.94
# October      7022232.93
# September    8702808.39
# Name: Amount, dtype: float64

# %%
month_order = [
    "January","February","March","April",
    "May","June","July","August",
    "September","October","November","December"
]

monthly_spending = (
    df.groupby("Month")["Amount"]
      .sum()
      .reindex(month_order)
)

plt.figure(figsize=(12,5))

monthly_spending.plot(marker="o")

plt.title("Monthly Spending")

plt.ylabel("Amount")

plt.grid(True)

plt.show()

# %%
top_merchants = (
    df.groupby("Description")["Amount"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

plt.figure(figsize=(12,5))

top_merchants.plot(kind="bar")

plt.title("Top 10 Merchants by Spending")

plt.ylabel("Amount")

plt.show()

# %%
highest = category_spending.idxmax()

print("Highest Spending Category :", highest)
# Out:
# Highest Spending Category : Electronics

# %%
df.to_csv("../datasets/cleaned_dataset.csv", index=False)
